# %% [markdown]
# # 数据科学基础 第四次作业

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.transforms import Bbox
from sklearn.datasets import make_classification
from sklearn.metrics import classification_report, zero_one_loss
from sklearn.cross_validation import train_test_split
from sklearn.ensemble import AdaBoostClassifier, BaggingClassifier, RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression, LinearRegression
% matplotlib inline

# %% [markdown]
# # 实验一：决策树深度对模型性能的影响

# %%
n_f = 30                    # 特征个数
inf_f = int(0.6 * n_f)   # 60%含信息特征
red_f = int(0.1 * n_f)   # 10%冗余特征(含信息特征的线性组合)
rep_f = int(0.1 * n_f)   # 10%重复特征(随机取自含信息特征和冗余特征)

# 创建分类数据集
X,y = make_classification(
    n_samples=1000,        # 实例个数
    flip_y=0.2,           # 随机抽20%实例改变类别,产生一些噪声
    n_features=n_f,
    n_informative=inf_f,
    n_redundant=red_f,
    n_repeated=rep_f,
    random_state=7)
# 划分为训练集,验证集,测试集
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.5,random_state=9)

# %%
# 验证模型深度的影响
single_train = []
single_test = []
for i in range(1,21):
    # 单决策树模型
    model = DecisionTreeClassifier(max_depth=i,min_samples_leaf=1)
    model.fit(X_train,y_train)
    # 单模型在验证集上预测
    y_pred = model.predict(X_train)
    single_train.append(1-zero_one_loss(y_train,y_pred))
    y_pred = model.predict(X_test)
    single_test.append(1-zero_one_loss(y_test,y_pred))
plt.figure(figsize=(10,4))
x_axis=range(1,21)
plt.plot(x_axis,single_train,marker='.',markersize=10)
plt.plot(x_axis,single_test,marker='.',markersize=10)
plt.plot([5,5],[0.6,1.05],c='r',linestyle='--')
plt.ylim([0.6,1.05])
plt.xticks(x_axis)
plt.xlabel('Depth')
plt.ylabel('Accuracy')
plt.legend(['train','test'])
plt.savefig('./figure/depth.pdf')
plt.show()

# %% [markdown]
# # 实验二：单独模型及组合模型性能对比

# %%
# 三种模型对比

# 单决策树模型
model = DecisionTreeClassifier(max_depth=5,min_samples_leaf=1)
model.fit(X_train,y_train)

# boosting集成
boosting = AdaBoostClassifier(
    DecisionTreeClassifier(max_depth=5,min_samples_leaf=1), 
    n_estimators=10,
    algorithm="SAMME",   
    random_state=9)
boosting.fit(X_train,y_train)

# bagging集成
bagging = BaggingClassifier(
    DecisionTreeClassifier(max_depth=5,min_samples_leaf=1), 
    n_estimators=10,
    bootstrap=True,
    max_samples=1.0,
    bootstrap_features=True,
    max_features=0.7,
    random_state=9)
bagging.fit(X_train,y_train)

# 单模型在验证集上预测
y_pred = model.predict(X_train)
print classification_report(y_train,y_pred)
print "Fraction of misclassification = %0.2f" % (zero_one_loss(y_train,y_pred)*100),"%"
y_pred = model.predict(X_test)
print classification_report(y_test,y_pred)
print "Fraction of misclassification = %0.2f" % (zero_one_loss(y_test,y_pred)*100),"%"

# 集成模型在验证集上预测 boosting
y_pred = boosting.predict(X_train)
print classification_report(y_train,y_pred)
print "Fraction of misclassification = %0.2f" % (zero_one_loss(y_train,y_pred)*100),"%"
y_pred = boosting.predict(X_test)
print classification_report(y_test,y_pred)
print "Fraction of misclassification = %0.2f" % (zero_one_loss(y_test,y_pred)*100),"%"

# 集成模型在验证集上预测 bagging
y_pred = bagging.predict(X_train)
print classification_report(y_train,y_pred)
print "Fraction of misclassification = %0.2f" % (zero_one_loss(y_train,y_pred)*100),"%"
y_pred = bagging.predict(X_test)
print classification_report(y_test,y_pred)
print "Fraction of misclassification = %0.2f" % (zero_one_loss(y_test,y_pred)*100),"%"
# Out:
#              precision    recall  f1-score   support
#
#           0       0.81      0.74      0.77      2475
#           1       0.76      0.83      0.79      2525
#
# avg / total       0.78      0.78      0.78      5000
#
# Fraction of misclassification = 21.74 %
#              precision    recall  f1-score   support
#
#           0       0.79      0.70      0.74      2521
#           1       0.73      0.81      0.77      2479
#
# avg / total       0.76      0.76      0.76      5000
#
# Fraction of misclassification = 24.36 %
#              precision    recall  f1-score   support
#
#           0       0.90      0.84      0.87      2475
#           1       0.86      0.91      0.88      2525
#
# avg / total       0.88      0.88      0.88      5000
#
# Fraction of misclassification = 12.18 %
#              precision    recall  f1-score   support
#
#           0       0.83      0.77      0.80      2521
#           1       0.78      0.85      0.81      2479
#
# avg / total       0.81      0.81      0.80      5000
#
# Fraction of misclassification = 19.48 %
#              precision    recall  f1-score   support
#
#           0       0.85      0.82      0.83      2475
#           1       0.83      0.85      0.84      2525
#
# avg / total       0.84      0.84      0.84      5000
#
# Fraction of misclassification = 16.36 %
#              precision    recall  f1-score   support
#
#           0       0.83      0.78      0.80      2521
#           1       0.79      0.83      0.81      2479
#
# avg / total       0.81      0.81      0.81      5000
#
# Fraction of misclassification = 19.24 %

# %% [markdown]
# # 实验三：分类器数量对组合模型性能的影响

# %%
boosting_acc = []
bagging_acc = []

for i in range(10,301,10):
    print(i)
    # boosting集成
    boosting = AdaBoostClassifier(
        DecisionTreeClassifier(max_depth=5,min_samples_leaf=1), 
        n_estimators=i,
        algorithm="SAMME",
        random_state=9)
    boosting.fit(X_train,y_train)
    
    # bagging集成
    bagging = BaggingClassifier(
        DecisionTreeClassifier(max_depth=5,min_samples_leaf=1), 
        n_estimators=i,
        bootstrap=True,
        max_samples=1.0,
        bootstrap_features=True,
        max_features=0.7,
        random_state=9)
    bagging.fit(X_train,y_train)
    
    y_pred = boosting.predict(X_test)
    print "Fraction of misclassification = %0.2f" % (zero_one_loss(y_test,y_pred)*100),"%"
    boosting_acc.append(1-zero_one_loss(y_test,y_pred))
    y_pred = bagging.predict(X_test)
    print "Fraction of misclassification = %0.2f" % (zero_one_loss(y_test,y_pred)*100),"%"
    bagging_acc.append(1-zero_one_loss(y_test,y_pred))
# Out:
# 10
# Fraction of misclassification = 19.48 %
# Fraction of misclassification = 19.24 %
# 20
# Fraction of misclassification = 19.10 %
# Fraction of misclassification = 19.04 %
# 30
# Fraction of misclassification = 18.38 %
# Fraction of misclassification = 18.70 %
# 40
# Fraction of misclassification = 18.16 %
# Fraction of misclassification = 18.48 %
# 50
# Fraction of misclassification = 17.28 %
# Fraction of misclassification = 18.10 %
# 60
# Fraction of misclassification = 17.02 %
# Fraction of misclassification = 17.82 %
# 70
# Fraction of misclassification = 16.44 %
# Fraction of misclassification = 17.76 %
# 80
# Fraction of misclassification = 16.60 %
# Fraction of misclassification = 17.78 %
# 90
# Fraction of misclassification = 16.34 %
# Fraction of misclassification = 17.60 %
# 100
# Fraction of misclassification = 16.00 %
# Fraction of misclassification = 17.76 %
# 110
# Fraction of misclassification = 15.78 %
# Fraction of misclassification = 17.92 %
# 120
# Fraction of misclassification = 15.68 %
# Fraction of misclassification = 17.76 %
# 130
# Fraction of misclassification = 15.44 %
# Fraction of misclassification = 17.74 %
# 140
# Fraction of misclassification = 15.28 %
# Fraction of misclassification = 17.80 %
# 150
# Fraction of misclassification = 15.34 %
# Fraction of misclassification = 17.76 %
# 160
# Fraction of misclassification = 15.92 %
# Fraction of misclassification = 17.62 %
# 170
# Fraction of misclassification = 15.28 %
# Fraction of misclassification = 17.66 %
# 180
# Fraction of misclassification = 15.04 %
# Fraction of misclassification = 17.62 %
# 190
# Fraction of misclassification = 15.16 %
# Fraction of misclassification = 17.72 %
# 200
# Fraction of misclassification = 14.74 %
# Fraction of misclassification = 17.78 %
# 210
# Fraction of misclassification = 14.66 %
# Fraction of misclassification = 17.54 %
# 220
# Fraction of misclassification = 14.72 %
# Fraction of misclassification = 17.72 %
# 230
# Fraction of misclassification = 15.18 %
# Fraction of misclassification = 17.82 %
# 240
# Fraction of misclassification = 15.02 %
# Fraction of misclassification = 17.70 %
# 250
# Fraction of misclassification = 14.98 %
# Fraction of misclassification = 17.74 %
# 260
# Fraction of misclassification = 14.84 %
# Fraction of misclassification = 17.82 %
# 270
# Fraction of misclassification = 14.82 %
# Fraction of misclassification = 17.78 %
# 280
# Fraction of misclassification = 14.72 %
# Fraction of misclassification = 17.72 %
# 290
# Fraction of misclassification = 14.78 %
# Fraction of misclassification = 17.72 %
# 300
# Fraction of misclassification = 14.82 %
# Fraction of misclassification = 17.72 %

# %%
plt.figure(figsize=(10,4))
x_axis = range(10,301,10)
plt.plot(x_axis,boosting_acc,marker='.',markersize=10)
plt.plot(x_axis,bagging_acc,marker='.',markersize=10)
plt.ylim([0.8,0.86])
plt.xlabel('#Estimator')
plt.ylabel('Accuracy')
plt.legend(['Boosting','Bagging'])
plt.savefig('./figure/nEstimator.pdf')
plt.show()

# %% [markdown]
# # 实验四：数据集噪声率对组合模型性能的影响

# %%
single_acc2 = []
boosting_acc2 = []
bagging_acc2 = []
for i in range(51):
    print(i)
    # 创建分类数据集
    X,y = make_classification(
        n_samples=1000,
        flip_y=0.01*i,
        n_features=n_f,
        n_informative=inf_f,
        n_redundant=red_f,
        n_repeated=rep_f,
        random_state=7)
    # 划分为训练集,验证集,测试集
    X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.5,random_state=9)
    
    # 单模型
    model = DecisionTreeClassifier(max_depth=5,min_samples_leaf=1)
    model.fit(X_train,y_train)
    
    # boosting集成
    boosting = AdaBoostClassifier(
        DecisionTreeClassifier(max_depth=5,min_samples_leaf=1), 
        n_estimators=50,
        algorithm="SAMME",
        random_state=9)
    boosting.fit(X_train,y_train)
    
    # bagging集成
    bagging = BaggingClassifier(
        DecisionTreeClassifier(max_depth=5,min_samples_leaf=1), 
        n_estimators=50,
        bootstrap=True,
        max_samples=1.0,
        bootstrap_features=True,
        max_features=0.7,
        random_state=9)
    bagging.fit(X_train,y_train)
    
    y_pred = model.predict(X_test)
    print "Fraction of misclassification = %0.2f" % (zero_one_loss(y_test,y_pred)*100),"%"
    single_acc2.append(1-zero_one_loss(y_test,y_pred))
    y_pred = boosting.predict(X_test)
    print "Fraction of misclassification = %0.2f" % (zero_one_loss(y_test,y_pred)*100),"%"
    boosting_acc2.append(1-zero_one_loss(y_test,y_pred))
    y_pred = bagging.predict(X_test)
    print "Fraction of misclassification = %0.2f" % (zero_one_loss(y_test,y_pred)*100),"%"
    bagging_acc2.append(1-zero_one_loss(y_test,y_pred))
# Out:
# 0
# Fraction of misclassification = 24.80 %
# Fraction of misclassification = 13.60 %
# Fraction of misclassification = 17.00 %
# 1
# Fraction of misclassification = 25.20 %
# Fraction of misclassification = 9.00 %
# Fraction of misclassification = 12.60 %
# 2
# Fraction of misclassification = 22.40 %
# Fraction of misclassification = 10.40 %
# Fraction of misclassification = 14.80 %
# 3
# Fraction of misclassification = 26.40 %
# Fraction of misclassification = 9.60 %
# Fraction of misclassification = 16.80 %
# 4
# Fraction of misclassification = 27.20 %
# Fraction of misclassification = 15.00 %
# Fraction of misclassification = 16.80 %
# 5
# Fraction of misclassification = 24.20 %
# Fraction of misclassification = 14.40 %
# Fraction of misclassification = 18.20 %
# 6
# Fraction of misclassification = 27.80 %
# Fraction of misclassification = 15.20 %
# Fraction of misclassification = 18.80 %
# 7
# Fraction of misclassification = 30.00 %
# Fraction of misclassification = 11.60 %
# Fraction of misclassification = 15.80 %
# 8
# Fraction of misclassification = 26.00 %
# Fraction of misclassification = 17.00 %
# Fraction of misclassification = 18.20 %
# 9
# Fraction of misclassification = 27.80 %
# Fraction of misclassification = 15.00 %
# Fraction of misclassification = 16.00 %
# 10
# Fraction of misclassification = 31.40 %
# Fraction of misclassification = 14.00 %
# Fraction of misclassification = 14.40 %
# 11
# Fraction of misclassification = 28.00 %
# Fraction of misclassification = 14.40 %
# Fraction of misclassification = 17.40 %
# 12
# Fraction of misclassification = 29.40 %
# Fraction of misclassification = 16.20 %
# Fraction of misclassification = 18.60 %
# 13
# Fraction of misclassification = 27.00 %
# Fraction of misclassification = 17.60 %
# Fraction of misclassification = 18.00 %
# 14
# Fraction of misclassification = 32.00 %
# Fraction of misclassification = 19.80 %
# Fraction of misclassification = 21.20 %
# 15
# Fraction of misclassification = 32.60 %
# Fraction of misclassification = 19.40 %
# Fraction of misclassification = 19.80 %
# 16
# Fraction of misclassification = 29.80 %
# Fraction of misclassification = 19.40 %
# Fraction of misclassification = 19.40 %
# 17
# Fraction of misclassification = 32.20 %
# Fraction of misclassification = 20.20 %
# Fraction of misclassification = 20.00 %
# 18
# Fraction of misclassification = 32.40 %
# Fraction of misclassification = 22.20 %
# Fraction of misclassification = 24.40 %
# 19
# Fraction of misclassification = 31.20 %
# Fraction of misclassification = 22.80 %
# Fraction of misclassification = 21.00 %
# 20
# Fraction of misclassification = 27.20 %
# Fraction of misclassification = 20.60 %
# Fraction of misclassification = 18.60 %
# 21
# Fraction of misclassification = 31.40 %
# Fraction of misclassification = 25.80 %
# Fraction of misclassification = 21.00 %
# 22
# Fraction of misclassification = 35.60 %
# Fraction of misclassification = 20.40 %
# Fraction of misclassification = 27.20 %
# 23
# Fraction of misclassification = 33.80 %
# Fraction of misclassification = 25.60 %
# Fraction of misclassification = 21.80 %
# 24
# Fraction of misclassification = 32.80 %
# Fraction of misclassification = 23.60 %
# Fraction of misclassification = 22.80 %
# 25
# Fraction of misclassification = 38.40 %
# Fraction of misclassification = 24.60 %
# Fraction of misclassification = 28.20 %
# 26
# Fraction of misclassification = 32.40 %
# Fraction of misclassification = 25.20 %
# Fraction of misclassification = 21.60 %
# 27
# Fraction of misclassification = 27.80 %
# Fraction of misclassification = 24.00 %
# Fraction of misclassification = 23.20 %
# 28
# Fraction of misclassification = 31.60 %
# Fraction of misclassification = 25.20 %
# Fraction of misclassification = 23.20 %
# 29
# Fraction of misclassification = 33.00 %
# Fraction of misclassification = 27.00 %
# Fraction of misclassification = 21.60 %
# 30
# Fraction of misclassification = 30.40 %
# Fraction of misclassification = 28.60 %
# Fraction of misclassification = 26.40 %
# 31
# Fraction of misclassification = 33.40 %
# Fraction of misclassification = 26.60 %
# Fraction of misclassification = 26.00 %
# 32
# Fraction of misclassification = 33.60 %
# Fraction of misclassification = 26.20 %
# Fraction of misclassification = 24.40 %
# 33
# Fraction of misclassification = 36.60 %
# Fraction of misclassification = 27.80 %
# Fraction of misclassification = 23.40 %
# 34
# Fraction of misclassification = 36.60 %
# Fraction of misclassification = 27.40 %
# Fraction of misclassification = 27.60 %
# 35
# Fraction of misclassification = 33.00 %
# Fraction of misclassification = 25.60 %
# Fraction of misclassification = 25.40 %
# 36
# Fraction of misclassification = 35.80 %
# Fraction of misclassification = 30.40 %
# Fraction of misclassification = 28.40 %
# 37
# Fraction of misclassification = 38.80 %
# Fraction of misclassification = 31.20 %
# Fraction of misclassification = 28.00 %
# 38
# Fraction of misclassification = 35.00 %
# Fraction of misclassification = 31.80 %
# Fraction of misclassification = 25.40 %
# 39
# Fraction of misclassification = 35.40 %
# Fraction of misclassification = 33.40 %
# Fraction of misclassification = 30.60 %
# 40
# Fraction of misclassification = 36.80 %
# Fraction of misclassification = 33.00 %
# Fraction of misclassification = 27.20 %
# 41
# Fraction of misclassification = 39.80 %
# Fraction of misclassification = 30.40 %
# Fraction of misclassification = 26.40 %
# 42
# Fraction of misclassification = 33.60 %
# Fraction of misclassification = 30.40 %
# Fraction of misclassification = 26.60 %
# 43
# Fraction of misclassification = 41.80 %
# Fraction of misclassification = 31.00 %
# Fraction of misclassification = 27.60 %
# 44
# Fraction of misclassification = 41.00 %
# Fraction of misclassification = 35.20 %
# Fraction of misclassification = 31.60 %
# 45
# Fraction of misclassification = 40.60 %
# Fraction of misclassification = 35.40 %
# Fraction of misclassification = 30.20 %
# 46
# Fraction of misclassification = 40.80 %
# Fraction of misclassification = 35.00 %
# Fraction of misclassification = 32.00 %
# 47
# Fraction of misclassification = 35.00 %
# Fraction of misclassification = 34.80 %
# Fraction of misclassification = 31.40 %
# 48
# Fraction of misclassification = 41.00 %
# Fraction of misclassification = 35.40 %
# Fraction of misclassification = 33.00 %
# 49
# Fraction of misclassification = 40.40 %
# Fraction of misclassification = 42.00 %
# Fraction of misclassification = 34.00 %
# 50
# Fraction of misclassification = 40.20 %
# Fraction of misclassification = 32.00 %
# Fraction of misclassification = 32.40 %

# %%
# flip比例的影响
# 比较准确率的均值和方差，画图
boo_acc2 = np.array(boosting_acc2)
bag_acc2 = np.array(bagging_acc2)
sin_acc2 = np.array(single_acc2)
print(boo_acc2.mean(),boo_acc2.std())
print(bag_acc2.mean(),bag_acc2.std())
print(sin_acc2.mean(),sin_acc2.std())

plt.figure(figsize=(10,5))
x_axis = np.arange(0,51)*0.01
plt.plot(x_axis,boosting_acc2,marker='.',markersize=10)
plt.plot(x_axis,bagging_acc2,marker='.',markersize=10)
# plt.ylim([0.8,0.86])
plt.xlabel('Flip%')
plt.ylabel('Accuracy')
plt.legend(['Boosting','Bagging'])
plt.savefig('./figure/flip.pdf')
plt.show()
# Out:
# (0.76031372549019605, 0.07923395246594496)
# (0.76737254901960772, 0.054794432515347477)
# (0.67227450980392145, 0.050077617571350701)

# %% [markdown]
# # 实验五：模型性能综合对比

# %%
# 创建分类数据集
X,y = make_classification(
    n_samples=1000, 
    flip_y=0.2,
    n_features=n_f,
    n_informative=inf_f,
    n_redundant=red_f,
    n_repeated=rep_f,
    random_state=7)
# 划分为训练集,验证集,测试集
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.5,random_state=9)

# %%
# 决策树

# 单模型
model = DecisionTreeClassifier(max_depth=5,min_samples_leaf=1)
model.fit(X_train,y_train)

# boosting集成
boosting = AdaBoostClassifier(
    DecisionTreeClassifier(max_depth=5,min_samples_leaf=1), 
    n_estimators=50,
    algorithm="SAMME",
    random_state=9)
boosting.fit(X_train,y_train)

# bagging集成
bagging = BaggingClassifier(
    DecisionTreeClassifier(max_depth=5,min_samples_leaf=1), 
    n_estimators=50, 
    bootstrap=True,
    max_samples=1.0,    
    bootstrap_features=True,
    max_features=0.7,      
    random_state=9)
bagging.fit(X_train,y_train)

# 单模型在验证集上预测
y_pred = model.predict(X_test)
print classification_report(y_test,y_pred)
print "Accuracy = %0.4f" % (1-zero_one_loss(y_test,y_pred))

# 集成模型在验证集上预测 boosting
y_pred = boosting.predict(X_test)
print classification_report(y_test,y_pred)
print "Accuracy = %0.4f" % (1-zero_one_loss(y_test,y_pred))

# 集成模型在验证集上预测 bagging
y_pred = bagging.predict(X_test)
print classification_report(y_test,y_pred)
print "Accuracy = %0.4f" % (1-zero_one_loss(y_test,y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.76      0.73      0.74       277
#           1       0.68      0.72      0.70       223
#
# avg / total       0.72      0.72      0.72       500
#
# Accuracy = 0.7220
#              precision    recall  f1-score   support
#
#           0       0.82      0.80      0.81       277
#           1       0.76      0.79      0.77       223
#
# avg / total       0.80      0.79      0.79       500
#
# Accuracy = 0.7940
#              precision    recall  f1-score   support
#
#           0       0.83      0.84      0.83       277
#           1       0.80      0.78      0.79       223
#
# avg / total       0.81      0.81      0.81       500
#
# Accuracy = 0.8140

# %%
# KNN

# 单模型
model = KNeighborsClassifier()
model.fit(X_train,y_train)

# bagging集成
bagging = BaggingClassifier(
    KNeighborsClassifier(), 
    n_estimators=50,  
    bootstrap=True,
    max_samples=1.0, 
    bootstrap_features=True,
    max_features=0.7, 
    random_state=9)
bagging.fit(X_train,y_train)

# 单模型在验证集上预测
y_pred = model.predict(X_test)
print classification_report(y_test,y_pred)
print "Accuracy = %0.4f" % (1-zero_one_loss(y_test,y_pred))

# 集成模型在验证集上预测 bagging
y_pred = bagging.predict(X_test)
print classification_report(y_test,y_pred)
print "Accuracy = %0.4f" % (1-zero_one_loss(y_test,y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.84      0.81      0.82       277
#           1       0.77      0.81      0.79       223
#
# avg / total       0.81      0.81      0.81       500
#
# Accuracy = 0.8080
#              precision    recall  f1-score   support
#
#           0       0.87      0.87      0.87       277
#           1       0.83      0.83      0.83       223
#
# avg / total       0.85      0.85      0.85       500
#
# Accuracy = 0.8520

# %%
# SVM

# 单模型
model = SVC()
model.fit(X_train,y_train)

# boosting集成
boosting = AdaBoostClassifier(
    SVC(), 
    n_estimators=50,
    algorithm="SAMME",
    random_state=9)
boosting.fit(X_train,y_train)

# bagging集成
bagging = BaggingClassifier(
    SVC(), 
    n_estimators=50,
    bootstrap=True,
    max_samples=1.0,
    bootstrap_features=True,
    max_features=0.7,
    random_state=9)
bagging.fit(X_train,y_train)

# 单模型在验证集上预测
y_pred = model.predict(X_test)
print classification_report(y_test,y_pred)
print "Accuracy = %0.4f" % (1-zero_one_loss(y_test,y_pred))

# 集成模型在验证集上预测 boosting
y_pred = boosting.predict(X_test)
print classification_report(y_test,y_pred)
print "Accuracy = %0.4f" % (1-zero_one_loss(y_test,y_pred))

# 集成模型在验证集上预测 bagging
y_pred = bagging.predict(X_test)
print classification_report(y_test,y_pred)
print "Accuracy = %0.4f" % (1-zero_one_loss(y_test,y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.71      0.92      0.80       277
#           1       0.85      0.54      0.66       223
#
# avg / total       0.77      0.75      0.74       500
#
# Accuracy = 0.7520
#              precision    recall  f1-score   support
#
#           0       0.55      1.00      0.71       277
#           1       0.00      0.00      0.00       223
#
# avg / total       0.31      0.55      0.40       500
#
# Accuracy = 0.5540
#              precision    recall  f1-score   support
#
#           0       0.75      0.92      0.83       277
#           1       0.87      0.62      0.73       223
#
# avg / total       0.80      0.79      0.78       500
#
# Accuracy = 0.7900

# %%
# Logistic回归

# 单模型
model = LogisticRegression()
model.fit(X_train,y_train)

# boosting集成
boosting = AdaBoostClassifier(
    LogisticRegression(), 
    n_estimators=50,
    algorithm="SAMME",
    random_state=9)
boosting.fit(X_train,y_train)

# bagging集成
bagging = BaggingClassifier(
    LogisticRegression(), 
    n_estimators=50,
    bootstrap=True,
    max_samples=1.0,
    bootstrap_features=True,
    max_features=0.7,
    random_state=9)
bagging.fit(X_train,y_train)

# 单模型在验证集上预测
y_pred = model.predict(X_test)
print classification_report(y_test,y_pred)
print "Accuracy = %0.4f" % (1-zero_one_loss(y_test,y_pred))

# 集成模型在验证集上预测 boosting
y_pred = boosting.predict(X_test)
print classification_report(y_test,y_pred)
print "Accuracy = %0.4f" % (1-zero_one_loss(y_test,y_pred))

# 集成模型在验证集上预测 bagging
y_pred = bagging.predict(X_test)
print classification_report(y_test,y_pred)
print "Accuracy = %0.4f" % (1-zero_one_loss(y_test,y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.78      0.72      0.75       277
#           1       0.68      0.75      0.72       223
#
# avg / total       0.74      0.73      0.73       500
#
# Accuracy = 0.7340
#              precision    recall  f1-score   support
#
#           0       0.78      0.78      0.78       277
#           1       0.73      0.73      0.73       223
#
# avg / total       0.76      0.76      0.76       500
#
# Accuracy = 0.7600
#              precision    recall  f1-score   support
#
#           0       0.83      0.78      0.80       277
#           1       0.75      0.79      0.77       223
#
# avg / total       0.79      0.79      0.79       500
#
# Accuracy = 0.7880

# %%
# 随机森林

model = RandomForestClassifier(n_estimators=50)
model.fit(X_train,y_train)

# 在验证集上预测
y_pred = model.predict(X_test)
print classification_report(y_test,y_pred)
print "Accuracy = %0.4f" % (1-zero_one_loss(y_test,y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.83      0.86      0.84       277
#           1       0.81      0.78      0.79       223
#
# avg / total       0.82      0.82      0.82       500
#
# Accuracy = 0.8200

# %%
plt.figure(figsize=(6,6))

# KNN
plt.scatter(0.808,0.81,marker='.',s=400,c='r')
plt.scatter(0.852,0.85,marker='x',s=100,c='r')
# 决策树
plt.scatter(0.722,0.72,marker='.',s=400,c='b')
plt.scatter(0.794,0.79,marker='*',s=200,c='b')
plt.scatter(0.814,0.81,marker='x',s=100,c='b')
# SVM
plt.scatter(0.752,0.74,marker='.',s=400,c='g')
plt.scatter(0.554,0.4,marker='*',s=200,c='g')
plt.scatter(0.79,0.78,marker='x',s=100,c='g')
# Logistic回归
plt.scatter(0.734,0.73,marker='.',s=400,c='y')
plt.scatter(0.76,0.76,marker='*',s=200,c='y')
plt.scatter(0.788,0.79,marker='x',s=100,c='y')
# 随机森林
plt.scatter(0.82,0.82,marker='.',s=400,c='m')

plt.legend(['KNN','KNN(Bagging)','DecisionTree','DecisionTree(Boosting)','DecisionTree(Bagging)','SVM','SVM(Boosting)','KNN(Bagging)','LogosticRegression','LogosticRegression(Boosting)','LogosticRegression(Bagging)','RandomForest'],
          loc='center left',bbox_to_anchor=(1.3, 0.5),fontsize=18)
plt.xlim([0.7,0.86])
plt.ylim([0.7,0.86])
plt.xlabel('Accuracy',fontsize=18)
plt.ylabel('F1-Score',fontsize=18)
plt.xticks([0.70,0.75,0.80,0.85],[0.70,0.75,0.80,0.85],fontsize=18)
plt.yticks([0.75,0.80,0.85],[0.75,0.80,0.85],fontsize=18)
plt.savefig('./figure/models.pdf',bbox_inches=Bbox([[-0.5,0],[12,6]]))
plt.show()
